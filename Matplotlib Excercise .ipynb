# %% [markdown]
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ## Import matplotlib.pyplot as plt and set %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Excercise 1
# ### Create a figure object called fig using plt.figure()
# ### use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis as ax
# ### Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.title('title')
plt.plot([0,20,40,60,100],
         [0,50,100,150,200])

# %% [markdown]
# ## Excercise 2
# ### Create a figure object and put two axes on it, ax1 and ax2.
# ### Located at [0,0,1,1] and [0.2,0.5,0.2,0.2] respectively.

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# ### Now plot (x,y) on both the axes. And call your figure object to show it.

# %%
plt.plot ([0,20,40,60,100],
         [0,50,100,150,200], color='red')
plt.xlabel('X', fontsize=15, color='green')
plt.ylabel('2*X', fontsize=15, color='green');

# %% [markdown]
# ## Excercise 3
# ### Create the plot below by adding the two axes to a figure object at [0,0,1,1] and [0.2,0.5,0.4,0.4]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1],[0.2,0.5,0.4,0.4])

# %% [markdown]
# ### Now use x,y and z arrays to recreate the plot below.
# ### Notice the x limits and y limits on the inserted plot.

# %% [markdown]
# ## Excercise 4
# ### use plt.subplots(nrows=1, ncols=2) to create the plot below.

# %%
plt.subplots(nrows=1,ncols=2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000026B69A1DD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B69A6A608>],
#        dtype=object))

# %% [markdown]
# ### Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style.

# %%
random_array = np.random.randn(20)
plt.subplots(random_array, color='blue', linestyle='--', linewidth=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-a3a4884036d0> in <module>
#       1 random_array = np.random.randn(20)
# ----> 2 plt.subplots(random_array, color='blue', linestyle='--', linewidth=3)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     544                                         frameon=frameon,
#     545                                         FigureClass=FigureClass,
# --> 546                                         **kwargs)
#     547
#     548         if figLabel:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3334         from matplotlib.figure import Figure
#    3335         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3336         fig = fig_cls(*args, **kwargs)
#    3337         return cls.new_figure_manager_given_figure(num, fig)
#    3338
#
# TypeError: __init__() got an unexpected keyword argument 'color'

# %% [markdown]
# ### resize the plot by adding the figsize() argument in plt.subplots()

# %%
fig = plt.figure(figsize=(9,9))
